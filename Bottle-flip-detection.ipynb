# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 7.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=ed7921c3c8c360402764e1ec06048f1f9ce9985e1cd5156456c5dfae74105565
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="aHyjT1pLFlIvcOTlCDwE")
project = rf.workspace("flipsy").project("flip-8w7ba")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.166, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Flip-1 in yolov8:: 100%|██████████| 259/259 [00:00<00:00, 750.07it/s]

# %%
from ultralytics import YOLO

# Load pretrained YOLO model
model = YOLO('yolov8n.pt')

# Train model using preprocessed custom data for 200 epochs
results = model.train(data='/content/Flip/data.yaml', epochs=200)

# Evaluate model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train11/weights/best.pt')

metrics = model.val()
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/Flip-1/val/labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100%|██████████| 25/25 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 48, len(boxes) = 49. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]
#                    all         25         49      0.964      0.545      0.673      0.561
# Speed: 6.5ms preprocess, 5.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val2
# array([    0.56148])

# %%
#  prediction inference with best performing model on video

model = YOLO('runs/detect/train11/weights/best.pt')

result = model.predict('IMG_1724.MOV')
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Example:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 103.3ms
# video 1/1 (2/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 7.9ms
# video 1/1 (3/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 6.1ms
# video 1/1 (4/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 8.3ms
# video 1/1 (5/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 7.8ms
# video 1/1 (6/128) /content/IMG_1724.MOV: 640x384 1 pepsi, 6.4ms
# ...
